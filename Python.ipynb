# %%
import pandas as pd
import time
import psutil
import os

process = psutil.Process(os.getpid())
cpu_cores = psutil.cpu_count(logical=True)

process.cpu_percent(interval=None)

mem_before = process.memory_info().rss / (1024 ** 2)  # MB
cpu_start = process.cpu_times().user + process.cpu_times().system
start_time = time.time()

df_rename_config_sem = pd.read_excel(
    "abfss://FabricCICDQA@onelake.dfs.fabric.microsoft.com/SemanticModelConfig.Lakehouse/Files/semantic1.xlsx",
    sheet_name="Sheet1"
)
end_time = time.time()
cpu_end = process.cpu_times().user + process.cpu_times().system
mem_after = process.memory_info().rss / (1024 ** 2)  # MB

rename_mapping_data = df_rename_config_sem.to_dict(orient="records")
df_rename_config = pd.DataFrame(rename_mapping_data)

elapsed = end_time - start_time
cpu_used = cpu_end - cpu_start
cus_consumed = (cpu_used * cpu_cores) / 3600  

print("Read Successfully ")
print(f"Time Taken: {elapsed:.4f} sec")
print(f"CUs Consumed: {cus_consumed:.6f} approx")
print(f"CPU Time Used: {cpu_used:.4f} sec")
print(f"Memory Used: {mem_after - mem_before:.2f} MB")
print(f"Data Size: {df_rename_config.shape[0]} rows × {df_rename_config.shape[1]} cols")
# Out:
# Read Successfully
# Time Taken: 0.1431 sec
# CUs Consumed: 0.000022 approx
# CPU Time Used: 0.0400 sec
# Memory Used: 0.00 MB
# Data Size: 6 rows × 5 cols

# %%
import pandas as pd
import time
import psutil
import re
import os

process = psutil.Process(os.getpid())
cpu_cores = psutil.cpu_count(logical=True)

mem_before = process.memory_info().rss / (1024 ** 2)  # MB
cpu_start = process.cpu_times().user + process.cpu_times().system
start_time = time.time()

df_rename_config['New Column'] = df_rename_config['Type'] * 2
df_rename_config['Current Name'].fillna('Unknown', inplace=True)

dq_report = {}
dq_report["Null Values"] = df_rename_config.isnull().sum().to_dict()
dq_report["Duplicate Rows"] = df_rename_config.duplicated().sum()

end_time = time.time()
cpu_end = process.cpu_times().user + process.cpu_times().system
mem_after = process.memory_info().rss / (1024 ** 2)  # MB

elapsed = end_time - start_time
cpu_used = cpu_end - cpu_start
cus_consumed = (cpu_used * cpu_cores) / 3600  

print("Data After Manipulation:")
print(df_rename_config.head())

print("DQ Report (Python):", dq_report)

print(f"Time Taken: {elapsed:.4f} sec")
print(f"CUs Consumed: {cus_consumed:.6f} approx")
print(f"CPU Time Used: {cpu_used:.4f} sec")
print(f"Memory Used: {mem_after - mem_before:.2f} MB")
print(f"Data Size: {df_rename_config.shape[0]} rows × {df_rename_config.shape[1]} cols")
# Out:
# Data After Manipulation:
#      Type      Table Name    Current Name      New Name  \
# 0   Table      Fact Table      Fact Table     SalesFact
# 1   Table  Customer Table  Customer Table   CustomerDim
# 2  Column       SalesFact           Sales   SalesAmount
# 3  Column       SalesFact       YearMonth   Year_Period
# 4  Column     CustomerDim        CustName  CustomerName
#
#                 Description    New Column
# 0          Sales Fact Table    TableTable
# 1  Customer Dimension Table    TableTable
# 2              Sales Amount  ColumnColumn
# 3         Year Month Period  ColumnColumn
# 4             Customer Name  ColumnColumn
# DQ Report (Python): {'Null Values': {'Type': 0, 'Table Name': 0, 'Current Name': 0, 'New Name': 0, 'Description': 0, 'New Column': 0}, 'Duplicate Rows': 0}
# Time Taken: 0.0671 sec
# CUs Consumed: 0.000006 approx
# CPU Time Used: 0.0100 sec
# Memory Used: 0.00 MB
# Data Size: 6 rows × 6 cols

# %%
import pandas as pd
import time

file_path = "abfss://4818cd05-d34c-4929-abfe-b2870c622eb9@onelake.dfs.fabric.microsoft.com/2501c47d-b4c5-407d-965f-9d790532bf28/Files/sales.xlsx"

# Read Excel directly from abfss:// using fsspec
df = pd.read_excel(file_path, engine="openpyxl", storage_options={"anon": True})

# Add calculated column
df["TotalSales"] = df["Quantity"] * df["UnitPrice"]

# Group by Item
start = time.time()
result_py = df.groupby("Item")["TotalSales"].sum().reset_index()
end = time.time()

print("Python GroupBy Time:", end - start, "seconds")
print(result_py.head())
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[4], line 7
#       4 file_path = "abfss://4818cd05-d34c-4929-abfe-b2870c622eb9@onelake.dfs.fabric.microsoft.com/2501c47d-b4c5-407d-965f-9d790532bf28/Files/sales.xlsx"
#       6 # Read Excel directly from abfss:// using fsspec
# ----> 7 df = pd.read_excel(file_path, engine="openpyxl", storage_options={"anon": True})
#       9 # Add calculated column
#      10 df["TotalSales"] = df["Quantity"] * df["UnitPrice"]
#
# File ~/jupyter-env/python3.11/lib/python3.11/site-packages/pandas/io/excel/_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File ~/jupyter-env/python3.11/lib/python3.11/site-packages/pandas/io/excel/_base.py:1580, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1577 self.engine = engine
#    1578 self.storage_options = storage_options
# -> 1580 self._reader = self._engines[engine](
#    1581     self._io,
#    1582     storage_options=storage_options,
#    1583     engine_kwargs=engine_kwargs,
#    1584 )
#
# File ~/jupyter-env/python3.11/lib/python3.11/site-packages/pandas/io/excel/_openpyxl.py:553, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     541 """
#     542 Reader using openpyxl engine.
#     543
#    (...)
#     550     Arbitrary keyword arguments passed to excel engine.
#     551 """
#     552 import_optional_dependency("openpyxl")
# --> 553 super().__init__(
#     554     filepath_or_buffer,
#     555     storage_options=storage_options,
#     556     engine_kwargs=engine_kwargs,
#     557 )
#
# File ~/jupyter-env/python3.11/lib/python3.11/site-packages/pandas/io/excel/_base.py:582, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     580 self.handles.handle.seek(0)
#     581 try:
# --> 582     self.book = self.load_workbook(self.handles.handle, engine_kwargs)
#     583 except Exception:
#     584     self.close()
#
# File ~/jupyter-env/python3.11/lib/python3.11/site-packages/pandas/io/excel/_openpyxl.py:570, in OpenpyxlReader.load_workbook(self, filepath_or_buffer, engine_kwargs)
#     565 def load_workbook(
#     566     self, filepath_or_buffer: FilePath | ReadBuffer[bytes], engine_kwargs
#     567 ) -> Workbook:
#     568     from openpyxl import load_workbook
# --> 570     return load_workbook(
#     571         filepath_or_buffer,
#     572         read_only=True,
#     573         data_only=True,
#     574         keep_links=False,
#     575         **engine_kwargs,
#     576     )
#
# File ~/jupyter-env/python3.11/lib/python3.11/site-packages/openpyxl/reader/excel.py:344, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     314 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     315                   data_only=False, keep_links=True, rich_text=False):
#     316     """Open the given filename and return the workbook
#     317
#     318     :param filename: the path to open or a file-like object
#    (...)
#     342
#     343     """
# --> 344     reader = ExcelReader(filename, read_only, keep_vba,
#     345                          data_only, keep_links, rich_text)
#     346     reader.read()
#     347     return reader.wb
#
# File ~/jupyter-env/python3.11/lib/python3.11/site-packages/openpyxl/reader/excel.py:123, in ExcelReader.__init__(self, fn, read_only, keep_vba, data_only, keep_links, rich_text)
#     121 def __init__(self, fn, read_only=False, keep_vba=KEEP_VBA,
#     122              data_only=False, keep_links=True, rich_text=False):
# --> 123     self.archive = _validate_archive(fn)
#     124     self.valid_files = self.archive.namelist()
#     125     self.read_only = read_only
#
# File ~/jupyter-env/python3.11/lib/python3.11/site-packages/openpyxl/reader/excel.py:95, in _validate_archive(filename)
#      88             msg = ('openpyxl does not support %s file format, '
#      89                    'please check you can open '
#      90                    'it with Excel first. '
#      91                    'Supported formats are: %s') % (file_format,
#      92                                                    ','.join(SUPPORTED_FORMATS))
#      93         raise InvalidFileException(msg)
# ---> 95 archive = ZipFile(filename, 'r')
#      96 return archive
#
# File ~/jupyter-env/python3.11/lib/python3.11/zipfile.py:1313, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1311 try:
#    1312     if mode == 'r':
# -> 1313         self._RealGetContents()
#    1314     elif mode in ('w', 'x'):
#    1315         # set the modified flag so central directory gets written
#    1316         # even if no files are added to the archive
#    1317         self._didModify = True
#
# File ~/jupyter-env/python3.11/lib/python3.11/zipfile.py:1380, in ZipFile._RealGetContents(self)
#    1378     raise BadZipFile("File is not a zip file")
#    1379 if not endrec:
# -> 1380     raise BadZipFile("File is not a zip file")
#    1381 if self.debug > 1:
#    1382     print(endrec)
#
# BadZipFile: File is not a zip file

# %%
import pandas as pd
import time
import psutil   # for CPU & memory usage

# File path
file_path = "abfss://4818cd05-d34c-4929-abfe-b2870c622eb9@onelake.dfs.fabric.microsoft.com/2501c47d-b4c5-407d-965f-9d790532bf28/Files/sales.xlsx"

# --- 1. Load Time ---
start = time.time()
df = pd.read_excel(file_path)
end = time.time()
print("Python Load Time:", end - start, "seconds")

# --- 2. Aggregation Time ---
start = time.time()
df["TotalSales"] = df["Quantity"] * df["UnitPrice"]
result_py = df.groupby("Item")["TotalSales"].sum().reset_index()
end = time.time()
print("Python GroupBy Time:", end - start, "seconds")

# --- 3. Memory & CPU Usage ---
process = psutil.Process()
mem_info = process.memory_info().rss / (1024 ** 2)  # in MB
cpu_usage = psutil.cpu_percent(interval=1)
print(f"Python Memory Usage: {mem_info:.2f} MB")
print(f"Python CPU Usage: {cpu_usage:.2f}%")

# --- 4. Rows Processed ---
print("Python Rows:", len(df))

# Show sample
print(result_py.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 10
#       8 # --- 1. Load Time ---
#       9 start = time.time()
# ---> 10 df = pd.read_excel(file_path)
#      11 end = time.time()
#      12 print("Python Load Time:", end - start, "seconds")
#
# File ~/jupyter-env/python3.11/lib/python3.11/site-packages/pandas/io/excel/_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File ~/jupyter-env/python3.11/lib/python3.11/site-packages/pandas/io/excel/_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1563     ext = inspect_excel_format(
#    1564         content_or_path=path_or_buffer, storage_options=storage_options
#    1565     )
#    1566     if ext is None:
# -> 1567         raise ValueError(
#    1568             "Excel file format cannot be determined, you must specify "
#    1569             "an engine manually."
#    1570         )
#    1572 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1573 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.
